# %%
import pandas as pd

# %%
df_log = pd.read_json('data/log_data/2018/11/2018-11-02-events.json', lines=True)
df_log = df_log[df_log['page'].str.contains("NextSong")] # Filter to only NextSong actions
#df_log = df_log[df_log['artist'].str.contains("Box")] # Filter to only NextSong actions
df_log.head(10)
# Out:
#                          artist       auth firstName gender  itemInSession  \
# 0     N.E.R.D. FEATURING MALICE  Logged In    Jayden      M              0
# 2           Death Cab for Cutie  Logged In   Stefany      F              1
# 3              Tracy Gang Pussy  Logged In   Stefany      F              2
# 4                       Skillet  Logged In     Kevin      M              0
# 5             Dance Gavin Dance  Logged In    Marina      F              0
# 7                         Dalto  Logged In     Aiden      M              1
# 8                    Kanye West  Logged In  Makinley      F              0
# 9   Jason Mraz & Colbie Caillat  Logged In     Kevin      M              0
# 10                 Liz Callaway  Logged In      Lily      F              0
# 11             The Decemberists  Logged In      Lily      F              1
#
#     lastName     length level                            location method  \
# 0        Fox  288.99220  free            New Orleans-Metairie, LA    PUT
# 2      White  216.42404  free                         Lubbock, TX    PUT
# 3      White  221.33506  free                         Lubbock, TX    PUT
# 4   Arellano  178.02404  free             Harrisburg-Carlisle, PA    PUT
# 5     Sutton  218.46159  free                         Salinas, CA    PUT
# 7       Hess  190.40608  free           La Crosse-Onalaska, WI-MN    PUT
# 8      Jones  278.88281  free  Chicago-Naperville-Elgin, IL-IN-WI    PUT
# 9   Arellano  189.62240  free             Harrisburg-Carlisle, PA    PUT
# 10      Koch  175.43791  paid  Chicago-Naperville-Elgin, IL-IN-WI    PUT
# 11      Koch  242.59873  paid  Chicago-Naperville-Elgin, IL-IN-WI    PUT
#
#         page   registration  sessionId  \
# 0   NextSong  1541033612796        184
# 2   NextSong  1540708070796         82
# 3   NextSong  1540708070796         82
# 4   NextSong  1540006905796        153
# 5   NextSong  1541064343796         47
# 7   NextSong  1540829025796        170
# 8   NextSong  1541091973796        118
# 9   NextSong  1540006905796        187
# 10  NextSong  1541048010796        172
# 11  NextSong  1541048010796        172
#
#                                                  song  status             ts  \
# 0                            Am I High (Feat. Malice)     200  1541121934796
# 2                     A Lack Of Color (Album Version)     200  1541122241796
# 3                                       I Have A Wish     200  1541122457796
# 4                             Monster (Album Version)     200  1541126568796
# 5                        Uneasy Hearts Weigh The Most     200  1541127957796
# 7                                      Falta Te Dizer     200  1541129674796
# 8                                     Family Business     200  1541135741796
# 9                               Lucky (Album Version)     200  1541137949796
# 10                  Journey To The Past  (LP Version)     200  1541149281796
# 11  Everything I Try to Do_ Nothing Seems to Turn ...     200  1541149456796
#
#                                             userAgent  userId
# 0   "Mozilla/5.0 (Windows NT 6.3; WOW64) AppleWebK...     101
# 2   "Mozilla/5.0 (Macintosh; Intel Mac OS X 10_9_4...      83
# 3   "Mozilla/5.0 (Macintosh; Intel Mac OS X 10_9_4...      83
# 4   "Mozilla/5.0 (Macintosh; Intel Mac OS X 10_9_4...      66
# 5   "Mozilla/5.0 (Macintosh; Intel Mac OS X 10_9_4...      48
# 7   "Mozilla/5.0 (Macintosh; Intel Mac OS X 10_9_4...      86
# 8   "Mozilla/5.0 (Windows NT 6.1; WOW64) AppleWebK...      17
# 9   "Mozilla/5.0 (Macintosh; Intel Mac OS X 10_9_4...      66
# 10  "Mozilla/5.0 (X11; Linux x86_64) AppleWebKit/5...      15
# 11  "Mozilla/5.0 (X11; Linux x86_64) AppleWebKit/5...      15

# %%
df_log['page'].unique()
# Out:
# array(['Home', 'NextSong', 'About', 'Logout', 'Login', 'Upgrade', 'Error',
#        'Settings', 'Help'], dtype=object)

# %%
df_song = pd.read_json('data/song_data/A/A/A/TRAAAAW128F429D538.json', lines=True)
print(df_song.dtypes)
df_song.head(5)
# Out:
# num_songs             int64
# artist_id            object
# artist_latitude     float64
# artist_longitude    float64
# artist_location      object
# artist_name          object
# song_id              object
# title                object
# duration            float64
# year                  int64
# dtype: object
#    num_songs           artist_id  artist_latitude  artist_longitude  \
# 0          1  ARMJAGH1187FB546F3         35.14968         -90.04892
#
#   artist_location   artist_name             song_id      title   duration  \
# 0     Memphis, TN  The Box Tops  SOCIWDW12A8C13D406  Soul Deep  148.03546
#
#    year
# 0  1969
